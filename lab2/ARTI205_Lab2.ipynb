# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-ab1a7561-c8c7-4b58-a533-964c39c7d0fe" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ab1a7561-c8c7-4b58-a533-964c39c7d0fe">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv('/content/ecommerce_sales_customer_analytics_150k.csv')

print("Dataset Shape:")
print(df.shape)

print("\nFirst 5 Rows:")
display(df.head())

print("\nColumn Names:")
print(df.columns.tolist())

print("\nData Types:")
print(df.dtypes)
# Out:
# Dataset Shape:
# (138116, 46)
#
# First 5 Rows:
#      order_id  order_date order_time order_status sales_channel  customer_id  \
# 0  ORD-301242  2023-11-06   16:37:47    Completed    Mobile App  CUST-003102
# 1  ORD-773460  2025-12-24   01:22:36    Completed       Website  CUST-003124
# 2  ORD-449374  2021-07-05   14:24:21    Completed    Mobile App  CUST-012496
# 3  ORD-567636  2023-01-21   07:20:26    Completed  Social Media  CUST-023928
# 4  ORD-820028  2022-05-13   09:46:21    Completed  Social Media  CUST-012730
#
#     customer_name  customer_age  gender customer_segment  ... discount_amount  \
# 0    Jasmine Ryan            55    Male         Consumer  ...          477.89
# 1     Scott Chase            26    Male          Premium  ...         1456.06
# 2    Marc Wheeler            69  Female          Premium  ...           97.30
# 3  Jennifer Smith            65    Male         Consumer  ...           53.34
# ...

# %%
print("Return Status:")
print(df['return_status'].value_counts())

print("\nDelivery Status:")
print(df['delivery_status'].value_counts())

print("\nCustomer Rating:")
print(df['customer_rating'].value_counts())
# Out:
# Return Status:
# return_status
# Returned    9462
# Name: count, dtype: int64
#
# Delivery Status:
# delivery_status
# On Time      86916
# Cancelled    24557
# Delayed      16886
# Early         9757
# Name: count, dtype: int64
#
# Customer Rating:
# customer_rating
# 3.7    9362
# 3.8    9263
# 3.6    9085
# 3.5    8755
# 3.9    8744
# 4.0    7718
# 3.4    7591
# 4.1    6628
# 3.3    6618
# 3.2    5502
# 4.2    5347
# 3.1    4476
# 4.3    4177
# 3.0    3407
# 4.4    3165
# 2.9    2527
# 4.5    2197
# 2.8    1806
# 4.6    1451
# 2.7    1288
# 4.7     917
# 2.6     898
# 2.5     571
# 4.8     551
# 5.0     386
# 4.9     337
# 2.4     313
# 2.3     219
# 2.2     131
# 2.1      73
# 2.0      32
# 1.9      11
# 1.8       8
# 1.7       3
# 1.6       2
# Name: count, dtype: int64

# %% [markdown]
# Machine Learning Problem
#
# Problem Type: Classification
#
# Target Variable: delivery_status
#
# Problem Statement:
# The goal of this machine learning project is to predict the delivery status of an e-commerce order based on the available customer and order information.
#
# The model will classify each order into one of four categories: On Time, Cancelled, Delayed, or Early.
